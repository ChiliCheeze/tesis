# %%
from faker import Faker
import pandas as pd
import numpy as np
import random 
import re

# %%
def remove_suffix(name):
    return re.sub(r'\b(Jr\.|Sr\.|II|III|IV|V)\b', '', name).strip()

def students(nStd = 239,seed=42):
    fake = Faker('en_PH')
    
    Faker.seed(seed)
    random.seed(seed)

    gPoint = [1.00, 1.25,1.50,1.75,2.00,2.25,2.50,2.75,3.00,4.00,6.00,9.00]
    weights = [50,65,60,65,50,50,50,50,50,1,0.5,0.5]

    Data = {
        'sName' : [fake.name() for i in range(nStd)],
        'Sub1': [random.choices(gPoint, weights=weights, k=1)[0]  for _ in range(nStd)],
        'Sub2': [random.choices(gPoint, weights=weights, k=1)[0]  for _ in range(nStd)],
        'Sub3': [random.choices(gPoint, weights=weights, k=1)[0]  for _ in range(nStd)],
        'Sub4': [random.choices(gPoint, weights=weights, k=1)[0]  for _ in range(nStd)],
        'Sub5': [random.choices(gPoint, weights=weights, k=1)[0]  for _ in range(nStd)],
        'Sub5': [random.choices(gPoint, weights=weights, k=1)[0]  for _ in range(nStd)],
        'Sub6': [random.choices(gPoint, weights=weights, k=1)[0]  for _ in range(nStd)],
        'Sub7': [random.choices(gPoint, weights=weights, k=1)[0]  for _ in range(nStd)],
        'Sub8': [random.choices(gPoint, weights=weights, k=1)[0]  for _ in range(nStd)]   
    }

    df = pd.DataFrame(Data)

    df['GWA'] = df[['Sub1', 'Sub2', 'Sub3', 'Sub4', 'Sub5', 'Sub6', 'Sub7', 'Sub8']].mean(axis=1, skipna=True).round(2)

    
    # map_values = {4.00:5.00, 6.00:None, 9.00:None}
    # df['Sub1'] = df['Sub1'].map(map_values).fillna(df['Sub1'])
    # df['Sub2'] = df['Sub2'].map(map_values).fillna(df['Sub2'])
    # df['Sub3'] = df['Sub3'].map(map_values).fillna(df['Sub3'])
    # df['Sub4'] = df['Sub4'].map(map_values).fillna(df['Sub4'])
    # df['Sub5'] = df['Sub5'].map(map_values).fillna(df['Sub5'])
    # df['Sub6'] = df['Sub6'].map(map_values).fillna(df['Sub6'])
    # df['Sub7'] = df['Sub7'].map(map_values).fillna(df['Sub7'])
    # df['Sub8'] = df['Sub8'].map(map_values).fillna(df['Sub8'])

    def grade_func(grade):
        if grade == 4:
            return 5.00
        elif grade in {6.00, 9.00}:
            return None
        else: 
            return grade

    for col in ['Sub1', 'Sub2', 'Sub3', 'Sub4', 'Sub5', 'Sub6', 'Sub7', 'Sub8']:
        df[col] = df[col].apply(grade_func)


    return df

# %%
df = students()
df
# Out:
#                sName  Sub1  Sub2  Sub3  Sub4  Sub5  Sub6  Sub7  Sub8   GWA
# 0       Allison Hill  2.25  2.25  2.75  1.75  2.75  2.50  2.50  1.25  2.25
# 1        Noah Rhodes  1.00  1.75  2.50  1.50  2.25  2.50  1.75  1.50  1.84
# 2    Angie Henderson  1.50  2.00  1.75  1.50  2.75  1.50  1.75  2.00  1.84
# 3      Daniel Wagner  1.25  2.00  1.00  1.00  3.00  1.00  2.00  1.25  1.56
# 4    Cristian Santos  2.50  3.00  1.50  3.00  1.00  2.00  1.25  1.25  1.94
# ..               ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 234    Michael Lyons  1.50  1.25  3.00  3.00  1.00  2.00  2.00  2.25  2.00
# 235   Kathryn Snyder  1.25  1.75  2.00  3.00  2.50  2.75  1.00  2.75  2.12
# 236  Andrew Reynolds  2.75  3.00  2.00  2.75  1.50  1.75  2.00  2.50  2.28
# 237      David Davis  1.50  2.00  1.00  1.75  2.50  2.75  2.00  1.00  1.81
# 238    Sara Johnston  2.25  2.50  1.00  2.50  2.25  2.50  2.00  1.75  2.09
#
# [239 rows x 10 columns]

# %%
df.to_csv('checkqlangPrt14.csv', index=False)

print("Done")
# Out:
# Done
